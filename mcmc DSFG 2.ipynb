# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import astropy.constants as cte
import astropy.units as un
import astropy.cosmology
from astropy.cosmology import Planck15 as cosmo
import emcee
import scipy.optimize as op

# %%
Msun=cte.M_sun
c=cte.c
b=2

# %%
file = open("/Users/mariajesusfloresmoraga/Desktop/DSFG/T1 f2.csv")
csvreader = csv.reader(file)
header = []
header = next(csvreader)

rows = []
for row in csvreader:
        rows.append(row)

ID= []

v1=[]
ev1=[]

v2=[]
ev2=[]

v3=[]
ev3=[]

l1=[]
el1=[]

l2=[]
el2=[]

l3=[]
el3=[]


for j in rows:   
    
    ID.append(j[0])
    
    v1.append(float(j[3]))
    ev1.append(float(j[4]))
    v2.append(float(j[5]))
    ev2.append(float(j[6]))
    v3.append(float(j[7]))
    ev3.append(float(j[8]))
    l1.append(float(j[9]))
    el1.append(float(j[10]))
    l2.append(float(j[11]))
    el2.append(float(j[12]))
    l3.append(float(j[13]))
    el3.append(float(j[14]))

# %%
v_=[148,218,278]*un.GHz
l__=[500,350,250]*un.um
v=v_.to("Hz").value
l_=c/(np.array([500,350,250])*un.um)
l=l_.to("Hz").value
vf=np.concatenate((v, l))

# %%
frecs0T=[v1[0],v2[0],v3[0],l1[0],l2[0],l3[0]]
errf0T=[ev1[0],ev2[0],ev3[0],el1[0],el2[0],el3[0]]

# %%
frecs0=np.array([[v1[0],v2[0],v3[0]],[l1[0],l2[0],l3[0]]])
errf0=np.array([[ev1[0],ev2[0],ev3[0]],[el1[0],el2[0],el3[0]]])

# %%
def tau(z,b,M_,d_,vf,v0): 
    M=Msun * 10** M_
    k0=0.15*(un.m**2/un.kg) 
    tau=k0*(vf/v0)**b *(z+1)**b * M/(np.pi*(d_/2)**2)
    return tau.to("")

# %%
def P(vf,T,z):
    h=cte.h
    K=cte.k_B
    A=2*h/(c**2)
    a=(h*vf*(1+z)/(K*T))
    B=vf**3/(np.e**(a.value) -1)
    P=(A*B).to("mJy")
    return P

# %%
def modelSv(z,T,b,M_,d_,vf,v0):
    D=cosmo.angular_diameter_distance(z)
    M=Msun*(10**M_)
    d=d_
    O=np.pi*(d/2)**2 * (D**-2)
    S_=O*(1-np.e**-tau(z,b,M_,d_,vf,v0))*P(vf,T,z)
    Sv=S_.to("mJy")   
    return Sv.value

# %% [markdown]
# MCMC
# This will show how you might use informative priors.
#
# Let's make sure it knows that the dust needs to be warmer than the CMB and that the amplitude needs to be positive.
#
# Also, "normal" galaxies have dust temperatures of ~25 K, with a dispersion of a few 2K. Let's set the prior on temperature to be a Gaussian centered at 25 K with a sigma of 2.5K.

# %%
z0=3.3
T0=56*un.K
M0_=9.45
d0_=2.9*un.kpc
Tc0=45.9*un.K

# %%
def lnlike(lnf,z,T,b,M_,d_,vf,v0,y, yerr):
    model = modelSv(z,T,b,M_,d_,vf,v0)
    inv_sigma2 = 1.0 / (yerr**2 + (model*un.mJy)**2 * np.exp(2*lnf))
    print(inv_sigma2)
    return -0.5 * np.sum((y-(model*un.mJy))**2*inv_sigma2 - np.log(inv_sigma2.value))

# %%
lnlike(-1,z0,T0,2,M0_,d0_,vf*un.Hz,353*un.Hz,frecs0T*un.mJy, errf0T*un.mJy)
# Out:
# [0.02161355 0.00642663 0.00253725 0.00066027 0.0006045  0.00103497] 1 / mJy2
# <Quantity -20.56152664>

# %%
def lnprior(T):
    print(T)
    if T >= 2.73:
        return -1 * (T - 25)**2 / (2 * 2.5**2)
    return -np.inf

# %%
def lnprob(lnf,z,T,b,M_,d_,vf,v0,y, yerr):
    lp = lnprior(T)
    if not(np.isfinite(lp)):
        return -np.inf
    return lp + lnlike(lnf,z,T,b,M_,d_,vf,v0,y, yerr)

# %% [markdown]
# ACT-S J0011-0018

# %%
(np.array(errf0T)*un.mJy)**2
# Out:
# <Quantity [ 4.9729,  9.6721, 94.8676, 54.9081, 40.0689, 52.5625] mJy2>

# %%
lnlike(-1,z0,T0,b,M0_,d0_,vf*un.Hz,350*un.GHz, np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy)
# Out:
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# <Quantity -17.12440462>

# %%
lnprob(-1,z0,T0.value,b,M0_,d0_,vf*un.Hz,350*un.GHz,np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy)
# Out:
# 56.0
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# <Quantity -94.00440462>

# %%
# initial guesses. 25K, arbitrary 
p0 = [-1,3.3,56,2,9.45,2.9]
args=(vf*un.Hz,np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy)
nll = lambda *args: -lnlike(-1,z0,T0,b,M0_,d0_,vf*un.Hz,350*un.GHz, np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy)
maxlike = op.minimize(nll, p0,args)
lnf0_fit,z0_fit,T0_fit,b_fit,M0_fit,d0_fit = maxlike["x"]
# Out:
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2

# %%
print(lnf0_fit,z0_fit,T0_fit,b_fit,M0_fit,d0_fit) # aquí se nota que los valores de ML son iguales que los ingresados
# Out:
# -1.0 3.3 56.0 2.0 9.45 2.9

# %%
modelSv(z0,T0,b,M0_,d0_,vf*un.Hz,(353*un.GHz))*un.mJy
# Out:
# <Quantity [  6.15510335,  20.0429737 ,  36.87010356, 103.76908774,
#            109.21273591,  82.16468646] mJy>

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.errorbar(vf,np.array(frecs0T), np.array(errf0T),
            ls='',
            marker='.',
            color='black',
            label='Herschel PACS+SPIRE')
ax.plot(vf,modelSv(z0,T0,b,M0_,d0_,vf*un.Hz,(353*un.GHz)),
        color='red',
        label='Max likelihood')
ax.set_ylabel(r'F$_{\nu}$')
ax.set_xlabel('$\lambda$ ($\mu m$)')
ax.set_xscale('log')
ax.legend(loc='best')

# %%
ndim, nwalkers = 6, 300
pos = [maxlike["x"] + 1e-4 * np.random.randn(ndim) for i in range(nwalkers)]
pos
# Out:
# [array([-1.00010603,  3.29981327, 56.00004415,  1.99997657,  9.44997743,
#          2.89993664]),
#  array([-0.99997293,  3.29997384, 55.99988849,  2.00004017,  9.45006142,
#          2.90005675]),
#          2.89995049]),
#  array([-1.00028052,  3.29998755, 56.00012157,  2.00003121,  9.45014686,
#          2.90021218]),
#  array([-0.9998238 ,  3.29997865, 55.99982671,  1.99994771,  9.45018187,
#          2.90010654]),
#  array([-1.00014256,  3.29999442, 56.00017321,  2.00008205,  9.45004011,
#          2.90003148]),
#  array([-0.99998204,  3.29988456, 55.99998811,  2.00019045,  9.45018249,
#          2.89988206]),
#  array([-1.00000419,  3.29994357, 56.00001138,  1.99982132,  9.4499177 ,
#          2.89989118]),
#  array([-1.00004641,  3.29987273, 55.99992   ,  1.99989763,  9.4501705 ,
#          2.9000006 ]),
#  array([-0.99993781,  3.30000243, 55.99998142,  1.99990939,  9.45013855,
#          2.90001926]),
#  array([-0.99999613,  3.30001121, 56.00009466,  1.99997433,  9.45000868,
#          2.90014745]),
#  array([-1.00006215,  3.30000512, 55.99993589,  2.00008625,  9.44996877,
#          2.90009216]),
#  array([-0.99987806,  3.2999533 , 55.99991602,  2.00006902,  9.45006683,
#          2.90007524]),
#  array([-1.00002581,  3.29988002, 56.00007503,  1.99998584,  9.44996251,
#          2.89996269]),
#  array([-0.99998141,  3.2998891 , 55.99997609,  1.9997837 ,  9.4499498 ,
#          2.89989687]),
#  array([-1.00018306,  3.29993532, 55.99986468,  2.00015761,  9.44994238,
#          2.89993701]),
#  array([-0.99992302,  3.29990912, 55.99992775,  1.99998991,  9.44986318,
#          2.90002877]),
#  array([-0.9999173 ,  3.30015633, 55.99996016,  2.00002892,  9.44999347,
#          2.89995685]),
#  array([-0.99990564,  3.30003558, 55.99986397,  2.00007106,  9.44996345,
#          2.9000425 ]),
#  array([-1.00011502,  3.29988938, 56.00003598,  1.99985668,  9.44984979,
#          2.90001954]),
#  array([-1.00002033,  3.29996744, 56.00006636,  1.9999742 ,  9.44999376,
#          2.89988673]),
#  array([-1.00021341,  3.2998572 , 55.99997226,  2.00012666,  9.45003349,
#          2.8999325 ]),
#  array([-0.9999635 ,  3.29999643, 56.00013139,  2.00014386,  9.44995964,
#          2.90006628]),
#  array([-1.00003676,  3.29999882, 56.00003686,  1.99997433,  9.45003301,
#          2.90001005]),
#  array([-1.00018514,  3.29995761, 55.99991826,  1.99997571,  9.45005146,
#          2.89990977]),
#  array([-1.00004038,  3.30022062, 55.99996793,  2.00007425,  9.44996841,
#          2.89984806]),
#  array([-1.00004853,  3.29994893, 55.99993044,  2.00010274,  9.44981673,
#          2.90005356]),
#  array([-1.00003605,  3.30002632, 55.99991865,  1.99999631,  9.45003649,
#          2.89995781]),
#  array([-1.00021199,  3.29991082, 56.00009758,  1.99995476,  9.4500762 ,
#          2.89988736]),
#  array([-0.99996904,  3.30001035, 55.99999789,  2.00007381,  9.45005241,
#          2.90002561]),
#  array([-1.00007766,  3.30000339, 55.99985129,  2.00002888,  9.45007923,
#          2.90001239]),
#  array([-1.00008398,  3.30005175, 55.99998923,  1.99991209,  9.44992374,
#          2.89979273]),
#  array([-1.0001333 ,  3.30005332, 55.99996913,  1.99996843,  9.44988808,
#          2.89986608]),
#  array([-1.00001237,  3.30011643, 55.99995057,  1.99974726,  9.45003104,
#          2.8999093 ]),
#  array([-1.00001465,  3.30003692, 56.0000906 ,  2.00002001,  9.4499038 ,
#          2.89993231]),
#  array([-0.99994258,  3.29999361, 55.99983832,  1.99996584,  9.45009197,
#          2.89992768]),
#  array([-0.99976934,  3.30005322, 56.00010835,  1.99987105,  9.45001384,
#          2.89986066]),
#  array([-0.99990187,  3.29999157, 56.00008009,  2.0000604 ,  9.44997996,
#          2.90004177]),
#  array([-0.99992222,  3.29997211, 56.00011469,  2.0000452 ,  9.44997111,
#          2.89997581]),
#  array([-1.00001196,  3.30002465, 56.00006611,  1.99999621,  9.4498621 ,
#          2.90006015]),
#  array([-0.99994695,  3.29984677, 55.99999151,  2.00006474,  9.45002832,
#          2.8998895 ]),
#  array([-0.99994323,  3.3000544 , 56.00002288,  2.00001537,  9.45019999,
#          2.89992676]),
#  array([-0.99995299,  3.3000705 , 56.0000438 ,  1.99990565,  9.45017314,
#          2.89998721]),
#  array([-1.00004676,  3.29996258, 56.00013773,  2.00000298,  9.44999151,
#          2.90015916]),
#  array([-1.0001157 ,  3.30009056, 55.9999894 ,  1.9999161 ,  9.44998703,
#          2.90005587]),
#  array([-1.00002008,  3.30003493, 56.00003268,  2.00021514,  9.4500681 ,
#          2.90003669]),
#  array([-0.99991018,  3.30000658, 56.00013939,  2.00003029,  9.45001428,
#          2.90004627]),
#  array([-0.9999647 ,  3.300018  , 56.00015841,  2.00007059,  9.44993502,
#          2.89989575]),
#  array([-1.0000296 ,  3.30006944, 56.00010923,  1.99987921,  9.45000342,
#          2.90018684]),
#  array([-0.99993826,  3.29998899, 56.00009214,  1.99998178,  9.44998579,
#          2.90002455]),
#  array([-0.99986691,  3.29984143, 56.00008211,  2.00003319,  9.45009074,
#          2.89994189]),
#  array([-0.9998574 ,  3.29989391, 55.99991876,  2.00014242,  9.44983984,
#          2.90012099]),
#  array([-1.00005558,  3.29997204, 55.99992786,  2.00005344,  9.44991256,
#          2.90012001]),
#  array([-0.99997252,  3.2999817 , 55.99992398,  1.99978558,  9.45000651,
#          2.90004373]),
#  array([-1.0000547 ,  3.30012338, 56.00003233,  1.99987465,  9.45005259,
#          2.8999818 ]),
#  array([-1.00018508,  3.29986918, 56.00019873,  2.00008115,  9.45004319,
#          2.89999171]),
#  array([-0.99994641,  3.30009558, 55.99989364,  1.99998715,  9.4497993 ,
#          2.89983097]),
#  array([-0.9999579 ,  3.30006333, 56.00005773,  1.99982634,  9.44981914,
#          2.89994831]),
#  array([-1.00004882,  3.30011065, 56.00015247,  1.99988893,  9.44980937,
#          2.9002488 ]),
#  array([-0.99997991,  3.29998222, 55.99989577,  1.99979623,  9.4501425 ,
#          2.89977472]),
#  array([-1.00013811,  3.30000922, 55.99998875,  1.99994415,  9.44993086,
#          2.90005613]),
#  array([-0.99996672,  3.29989201, 55.99999285,  1.99995412,  9.44998   ,
#          2.89976551]),
#  array([-1.00000665,  3.29996387, 55.99998604,  2.00003935,  9.45009547,
#          2.90022683]),
#  array([-1.00003314,  3.29998384, 56.00001413,  2.00005126,  9.44994856,
#          2.89986703]),
#  array([-1.00008153,  3.2999906 , 56.00007832,  2.00007931,  9.44999277,
#          2.90007666]),
#  array([-0.99998493,  3.29987484, 55.99993886,  1.99994753,  9.44995495,
#          2.89998373])]

# %%
nthreads=2

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim,lnprob(-1,z0,T0.value,b,M0_,d0_,vf*un.Hz,350*un.GHz,np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy) ,
                                args=(vf*un.Hz,np.array(frecs0T) *un.mJy, np.array(errf0T)*un.mJy),
                                threads=nthreads)

sampler.run_mcmc(pos, 1000)
samples = sampler.chain[:, 100:, :].reshape((-1, ndim))
# Out:
# 56.0
# [0.09764179 0.01534635 0.0035525  0.00066117 0.0006045  0.00103497] 1 / mJy2
# emcee: Exception while calling your likelihood function:
#   params: [-1.00010603  3.29981327 56.00004415  1.99997657  9.44997743  2.89993664]
#   args: (<Quantity [1.48000000e+11, 2.18000000e+11, 2.78000000e+11, 5.99584916e+11,
#            8.56549880e+11, 1.19916983e+12] Hz>, <Quantity [  6.02,  21.93,  28.43,  94.65, 120.18,  89.41] mJy>, <Quantity [2.23, 3.11, 9.74, 7.41, 6.33, 7.25] mJy>)
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
# TypeError: 'Quantity' object is not callable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-a371200cc6ba> in <module>
#       3                                 threads=nthreads)
#       4
# ----> 5 sampler.run_mcmc(pos, 1000)
#       6 samples = sampler.chain[:, 100:, :].reshape((-1, ndim))
#
# /opt/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     441
#     442         results = None
# --> 443         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444             pass
#     445
#
# /opt/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     342             state.blobs = blobs0
#     343         if state.log_prob is None:
# --> 344             state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     345         if np.shape(state.log_prob) != (self.nwalkers,):
#     346             raise ValueError("incompatible input dimensions")
#
# /opt/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     487             else:
#     488                 map_func = map
# --> 489             results = list(map_func(self.log_prob_fn, p))
#     490
#     491         try:
#
# /opt/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in __call__(self, x)
#     622     def __call__(self, x):
#     623         try:
# --> 624             return self.f(x, *self.args, **self.kwargs)
#     625         except:  # pragma: no cover
#     626             import traceback
#
# TypeError: 'Quantity' object is not callable
